# %%
import numpy as np
import pandas as pd
import os
import re
import astropy.units as u
import sys
import multiprocessing as mp
import tqdm

import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from matplotlib import rc
plt.style.use('classic')
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)
rc('figure', facecolor='none')
rc('xtick', labelsize=50)
rc('ytick', labelsize=50)
mpl.rcParams['axes.linewidth'] = 2

# sys.path.append(os.path.realpath("/home/jbirky/Tresorit/packages/vplanet"))
sys.path.append(os.path.realpath("/home/jbirky/Tresorit/packages/vplanet_inference"))

import vplanet_inference as vpi
sys.path.append(os.path.realpath("../src"))

# %%
inpath = os.path.join(vpi.INFILE_DIR, "eqtide/ctl")

inparams = {
            "primary.dMass": u.Msun, 
            "secondary.dMass": u.Msun, 
            "primary.dRadius": u.Rsun, 
            "secondary.dRadius": u.Rsun, 
            "primary.dRotPeriod": u.day, 
            "secondary.dRotPeriod": u.day, 
            "primary.dTidalTau": u.dex(u.s), 
            "secondary.dTidalTau": u.dex(u.s), 
            "secondary.dEcc": u.dimensionless_unscaled, 
            "secondary.dOrbPeriod": u.day,
            "vpl.dStopTime": u.Gyr
}

outparams = {
             "final.primary.RotPer": u.day, 
             "final.secondary.Eccentricity": u.dimensionless_unscaled,
             "final.secondary.OrbPeriod": u.day,
             "final.secondary.RotPer": u.day
}

ctl = vpi.VplanetModel(inparams, inpath=inpath, outparams=outparams, 
                       verbose=False, timesteps=1e5*u.yr, time_init=5e6*u.yr)

def run_models(vpm, theta_var_array, ncore=4):
    with mp.Pool(ncore) as p:
        outputs = []
        for result in tqdm.tqdm(p.imap(func=vpm.run_model, iterable=theta_var_array), total=len(theta_var_array)):
            outputs.append(result)
        outputs = np.array(outputs)
    return outputs

def plot_evolution_panel(sims1, sims2, sims3, qplot, ls=50, lw=1.5, 
                         savename="evol_plot.png",
                         cb_label=r'$\log(\tau)$ [dex(s)]', 
                         cmap=mpl.cm.jet):
    
    results = [str(tv) for tv in qplot]
    
    c = np.arange(0, len(sims1))
    norm = mpl.colors.Normalize(vmin=c.min(), vmax=c.max())
    cmap = mpl.cm.ScalarMappable(norm=norm, cmap=cmap)
    cmap.set_array([])

    fig, axs = plt.subplots(1, 3, figsize=[40,15], sharex=True, sharey=True)
    fig.subplots_adjust(wspace=0.18)

    for ii in range(len(results)):

        # axs[0].plot(sims1[ii]['Time'], sims1[ii]['final.secondary.OrbPeriod'] / sims1[ii]['final.primary.RotPer'], lw=lw, c=cmap.to_rgba(ii))
        # axs[1].plot(sims2[ii]['Time'], sims2[ii]['final.secondary.OrbPeriod'] / sims2[ii]['final.primary.RotPer'], lw=lw, c=cmap.to_rgba(ii))
        # im = axs[2].plot(sims3[ii]['Time'], sims3[ii]['final.secondary.OrbPeriod'] / sims3[ii]['final.primary.RotPer'], lw=lw, c=cmap.to_rgba(ii))

        axs[0].plot(sims1[ii]['Time'], sims1[ii]['final.primary.RotPer'] / sims1[ii]['final.secondary.OrbPeriod'], lw=lw, c=cmap.to_rgba(ii))
        axs[1].plot(sims2[ii]['Time'], sims2[ii]['final.primary.RotPer'] / sims2[ii]['final.secondary.OrbPeriod'], lw=lw, c=cmap.to_rgba(ii))
        im = axs[2].plot(sims3[ii]['Time'], sims3[ii]['final.primary.RotPer'] / sims3[ii]['final.secondary.OrbPeriod'], lw=lw, c=cmap.to_rgba(ii))

    plt.minorticks_on()
    cb = fig.colorbar(cmap, ticks=c, ax=axs, orientation='vertical', pad=.02)
    cb.set_label(cb_label, fontsize=ls)
    cb.ax.set_yticklabels(qplot)

    # axs[0].set_yscale('log')
    # axs[1].set_yscale('log')
    # axs[2].set_yscale('log')
    plt.xscale('log')
    plt.xlim(9e5, 8e9)
    # plt.ylim(5e-1, 2e2)
    
    axs[0].set_title("Porb/Prot (Porb init = 5)", fontsize=ls)
    axs[1].set_title("Porb/Prot (Porb init = 10)", fontsize=ls)
    axs[2].set_title("Porb/Prot (Porb init = 15)", fontsize=ls)
    axs[0].set_xlabel('Time [yr]', fontsize=ls)
    axs[1].set_xlabel('Time [yr]', fontsize=ls)
    axs[2].set_xlabel('Time [yr]', fontsize=ls)
    axs[0].minorticks_on()
    axs[1].minorticks_on()
    axs[2].minorticks_on()
    # plt.savefig(savename, bbox_inches='tight', transparent=True)
    plt.show()

    return fig

# %%
tvals = np.round(np.arange(-4, 2, .4),1)

nsim = len(tvals)
mass1 = np.ones(nsim)
mass2 = np.ones(nsim)
rad1 = np.ones(nsim)
rad2 = np.ones(nsim)
prot1 = 0.5 * np.ones(nsim)
prot2 = 0.5 * np.ones(nsim)
ecc = 0.2 * np.ones(nsim)
ages = 8 * np.ones(nsim)

porb1 = 5 * np.ones(nsim)
porb2 = 10 * np.ones(nsim)
porb3 = 15 * np.ones(nsim)

theta_tau1 = np.array([mass1, mass2, rad1, rad2, prot1, prot2, tvals, tvals, ecc, porb1, ages]).T
theta_tau2 = np.array([mass1, mass2, rad1, rad2, prot1, prot2, tvals, tvals, ecc, porb2, ages]).T
theta_tau3 = np.array([mass1, mass2, rad1, rad2, prot1, prot2, tvals, tvals, ecc, porb3, ages]).T

# %%
ctl_evol1 = run_models(ctl, theta_tau1, ncore=6)
ctl_evol2 = run_models(ctl, theta_tau2, ncore=6)
ctl_evol3 = run_models(ctl, theta_tau3, ncore=6)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
#   7%|▋         | 1/15 [00:06<01:33,  6.69s/it]ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  13%|█▎        | 2/15 [00:08<00:47,  3.65s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  40%|████      | 6/15 [00:11<00:10,  1.15s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  47%|████▋     | 7/15 [00:16<00:17,  2.17s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  53%|█████▎    | 8/15 [00:18<00:15,  2.21s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  73%|███████▎  | 11/15 [00:19<00:04,  1.15s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  87%|████████▋ | 13/15 [00:21<00:02,  1.15s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# 100%|██████████| 15/15 [00:22<00:00,  1.51s/it]
#   0%|          | 0/15 [00:00<?, ?it/s]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ...
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  60%|██████    | 9/15 [01:02<00:32,  5.34s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
#  67%|██████▋   | 10/15 [01:02<00:21,  4.25s/it]ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
#  73%|███████▎  | 11/15 [01:06<00:16,  4.03s/it]ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 60 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 65 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 66 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 67 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 68 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 69 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 86 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 87 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 129 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 134 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 135 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 136 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 137 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 138 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 167 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 168 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 221 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 226 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 227 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 228 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 229 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 230 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 247 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 248 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 290 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 295 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 296 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 297 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 298 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 299 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 328 of system.log: Cannot interpret unit `(null)`.
# ERROR:Error processing line 329 of system.log: Cannot interpret unit `(null)`.
# 100%|██████████| 15/15 [01:20<00:00,  5.37s/it]

# %%
fig = plot_evolution_panel(ctl_evol1, ctl_evol2, ctl_evol3, tvals, cb_label=r'$\log(\tau)$ [dex(s)]', cmap=mpl.cm.coolwarm, lw=3)
fig.savefig("../apj_submission2/eqtide_ctl_ratio.png", bbox_inches='tight')
